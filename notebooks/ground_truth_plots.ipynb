# %%
import xarray as xr
import matplotlib.pyplot as plt
import imageio
import os

data_dir = r"C:\Users\micke\Downloads\dfda178b22d3772b9b9b0118dba68a02.nc"
data = xr.open_dataset(data_dir)
data["longitude"] = (data["longitude"]+180) % 360 -180

data = data.sortby("longitude")
data
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:         (valid_time: 24, pressure_level: 17, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B ...
#   * valid_time      (valid_time) datetime64[ns] 192B 2022-09-28 ... 2022-09-2...
#   * pressure_level  (pressure_level) float64 136B 850.0 825.0 ... 225.0 200.0
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB -180.0 -179.8 ... 179.5 179.8
#     expver          (valid_time) <U4 384B ...
# Data variables:
#     z               (valid_time, pressure_level, latitude, longitude) float32 2GB ...
#     t               (valid_time, pressure_level, latitude, longitude) float32 2GB ...
#     u               (valid_time, pressure_level, latitude, longitude) float32 2GB ...
#     v               (valid_time, pressure_level, latitude, longitude) float32 2GB ...
# ...

# %%
# -------------------------------
# User settings
# -------------------------------

                      # your xarray dataset
var = 'v'        # <-- specify variable to plot
time_dim = "valid_time"                 # or "valid_time", depending on dataset
pressure_dim = "pressure_level"
lat_dim = "latitude"
lon_dim = "longitude"

# -------------------------------
# Output directory setup
# -------------------------------

top_dir = f"./{var}"
os.makedirs(top_dir, exist_ok=True)

# -------------------------------
# Loop over pressure levels
# -------------------------------

pressure_levels = data[pressure_dim].values

for p in pressure_levels:

    sub_dir = os.path.join(top_dir, f"{pressure_dim}_{int(p)}")
    os.makedirs(sub_dir, exist_ok=True)

    frames = []   # store file paths for GIF assembly

    data_p = data[var].sel({pressure_dim: p})

    # Iterate through each time step
    for idx, t in enumerate(data_p[time_dim].values):

        da_plot = data_p.sel({time_dim: t})

        fig, ax = plt.subplots(figsize=(10, 5))
        im = da_plot.plot(ax=ax, cmap="viridis", add_colorbar=True, )

        ax.set_title(f"{var} — {pressure_dim}={p} — time={str(t)}")

        # Save image
        frame_path = os.path.join(sub_dir, f"frame_{idx:03d}.png")
        plt.savefig(frame_path, dpi=150, bbox_inches="tight")
        plt.close(fig)

        frames.append(frame_path)

    # -------------------------------
    # Build GIF for this pressure level
    # -------------------------------
    gif_path = os.path.join(sub_dir, f"{var}_{int(p)}.gif")

    with imageio.get_writer(gif_path, mode="I", duration=0.3) as writer:
        for frame in frames:
            writer.append_data(imageio.imread(frame))

    print(f"Saved GIF for pressure level {p}: {gif_path}")
# Out:
# C:\Users\micke\AppData\Local\Temp\ipykernel_19420\1423073332.py:58: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame))
# Saved GIF for pressure level 850.0: ./u\pressure_level_850\u_850.gif
# Saved GIF for pressure level 825.0: ./u\pressure_level_825\u_825.gif
# Saved GIF for pressure level 800.0: ./u\pressure_level_800\u_800.gif
# Saved GIF for pressure level 775.0: ./u\pressure_level_775\u_775.gif
# Saved GIF for pressure level 750.0: ./u\pressure_level_750\u_750.gif
# Saved GIF for pressure level 700.0: ./u\pressure_level_700\u_700.gif
# Saved GIF for pressure level 650.0: ./u\pressure_level_650\u_650.gif
# Saved GIF for pressure level 600.0: ./u\pressure_level_600\u_600.gif
# ...
